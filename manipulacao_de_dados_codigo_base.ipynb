R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 4                 1.181                  0.078  ...                 1.400
# 5                 1.383                  0.132  ...                 2.050
# 6                 1.453                  0.218  ...                 1.950
# 7                 1.631                  0.158  ...                 2.000
# 8                 1.284                  0.130  ...                 1.699
# 9                 1.224                  0.141  ...                 1.700
# 10                1.573                  0.134  ...                 1.780
# 11                1.276                  0.116  ...                 1.590
# 12                1.301                  0.109  ...                 1.750
# 13                1.805                  0.134  ...                 1.980
# 14                1.785                  0.035  ...                 1.850
# 15                1.578                  0.123  ...                 1.850
# 16                1.914                  0.246  ...                 2.400
# 17                1.545                  0.141  ...                 1.990
# 18                1.300                  0.000  ...                 1.300
#
#     MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 4                   0.24                    0.066                     0.941
# 5                  0.426                    0.095                     0.957
# 6                  0.353                    0.150                       1.1
# 7                  0.515                    0.097                     1.116
# 8                  0.353                    0.101                     0.931
# 9                  0.277                    0.115                     0.947
# 10                 0.494                    0.085                     1.079
# 11                 0.332                    0.091                     0.944
# 12                 0.321                    0.084                      0.98
# 13                 0.689                    0.074                     1.116
# 14                 0.412                    0.020                     1.373
# 15                 0.441                    0.078                     1.137
# 16                 0.536                    0.129                     1.378
# 17                 0.533                    0.091                     1.012
# 18                 0.202                    0.000                     1.098
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 4                       0.077                    0.7441
# 5                       0.128                    0.5686
# 6                       0.068                    0.7332
# 7                       0.091                    0.9923
# 8                       0.072                    0.7577
# 9                       0.091                    0.5643
# 10                      0.078                    0.8857
# 11                      0.078                    0.7119
# 12                      0.052                    0.8267
# 13                      0.171                     0.767
# 14                      0.167                    0.8339
# 15                      0.068                    0.9515
# 16                      0.237                    0.7564
# 17                      0.149                      0.52
# 18                      0.096                    0.9798
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 4                     1.0317                         0.082   5  2004
# 5                       1.35                         0.134   5  2004
# 6                      1.294                         0.062   5  2004
# 7                    1.36183                         0.082   5  2004
# 8                     1.2972                         0.077   5  2004
# 9                     1.3541                         0.096   5  2004
# 10                    1.2499                         0.072   5  2004
# 11                    1.1386                         0.083   5  2004
# 12                    1.1059                         0.053   5  2004
# 13                    1.2992                         0.153   5  2004
# 14                    1.4912                         0.122   5  2004
# 15                    1.2109                          0.06   5  2004
# 16                    1.8908                         0.172   5  2004
# 17                    1.3306                         0.147   5  2004
# 18                    1.3577                         0.087   5  2004
#
# [15 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
# lendo os primeiros elementos do dataframe.

n = 6
data.head(n)

# "n" dentro de "()" informa o tanto de elementos a serem exibidos, que no caso será o valor de "n".
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
#
# [6 rows x 21 columns]

# %%
# lendo agora os últimos elementos do dataframe

n = 4
data.tail(n)

# "n" dentro de "()" informa o tanto de elementos a serem exibidos, que no caso será o valor de "n".
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO             ESTADO  \
# 106819      106819   2019-06-23  2019-06-29       SUL  RIO GRANDE DO SUL
# 106820      106820   2019-06-23  2019-06-29       SUL     SANTA CATARINA
# 106821      106821   2019-06-23  2019-06-29   SUDESTE          SAO PAULO
# 106822      106822   2019-06-23  2019-06-29  NORDESTE            SERGIPE
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 106819     GNV                            23             R$/m3
# 106820     GNV                            24             R$/m3
# 106821     GNV                            52             R$/m3
# 106822     GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 106819                3.401                  0.129  ...                 3.789
# 106820                2.912                  0.190  ...                 3.499
# 106821                3.020                  0.229  ...                 3.490
# 106822                3.697                  0.005  ...                 3.699
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 106819                  0.95                    0.038
# 106820                 0.914                    0.065
# 106821                 0.646                    0.076
# 106822                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [4 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
# exibindo informações sobre o dataframe

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data.shape
# Out:
# (106823, 21)

# %%
# ou melhor...

print(f'Linhas: {data.shape[0]}\nColunas: {data.shape[1]}')
# Out:
# Linhas: 106823
# Colunas: 21

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
alunos_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70, 15, 60],
    'eh jedi': [True, True, False]  # o nome das colunas podem ter espaços
})

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      int64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 203.0+ bytes

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O atributo `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
alunos_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
type(alunos_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(alunos_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df_rename = alunos_df.rename(columns={
    'nome': 'Nome completo',
    'idade': 'Idade'
})

# %%
alunos_df_rename.columns
# Out:
# Index(['Nome completo', 'Idade', 'peso', 'eh jedi'], dtype='object')

# %%
# dataframe com as colunas com nome original

alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
alunos_df.rename(columns={'nome': 'Nome completo', 'idade': 'Idade'}, inplace=True)

# %%
alunos_df
# Out:
#     Nome completo  Idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as listas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
alunos_df.columns = ['NOME', 'IDADE', 'PESO', 'NERD']

# %%
alunos_df.columns
# Out:
# Index(['NOME', 'IDADE', 'PESO', 'NERD'], dtype='object')

# %%
alunos_df
# Out:
#              NOME  IDADE  PESO   NERD
# 0  Luke Skywalker     16    70   True
# 1            Yoda   1000    15   True
# 2       Palpatine     70    60  False

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.iloc[106821]
# Out:
# Unnamed: 0                           106821
# DATA INICIAL                     2019-06-23
# DATA FINAL                       2019-06-29
# REGIÃO                              SUDESTE
# ESTADO                            SAO PAULO
# PRODUTO                                 GNV
# NÚMERO DE POSTOS PESQUISADOS             52
# UNIDADE DE MEDIDA                     R$/m3
# PREÇO MÉDIO REVENDA                    3.02
# DESVIO PADRÃO REVENDA                 0.229
# PREÇO MÍNIMO REVENDA                  2.699
# PREÇO MÁXIMO REVENDA                   3.49
# MARGEM MÉDIA REVENDA                  0.646
# COEF DE VARIAÇÃO REVENDA              0.076
# PREÇO MÉDIO DISTRIBUIÇÃO              2.374
# DESVIO PADRÃO DISTRIBUIÇÃO            0.165
# PREÇO MÍNIMO DISTRIBUIÇÃO            2.0179
# PREÇO MÁXIMO DISTRIBUIÇÃO            2.5093
# COEF DE VARIAÇÃO DISTRIBUIÇÃO          0.07
# MÊS                                       6
# ANO                                    2019
# Name: 106821, dtype: object

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([1, 4, 7, 6])
# Out:
# 0    1
# 1    4
# 2    7
# 3    6
# dtype: int64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([2.4, 5.6, 7.8])
# Out:
# 0    2.4
# 1    5.6
# 2    7.8
# dtype: float64

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %%
produto_view= data['PRODUTO'] # a series referente á coluna, NÃO É UMA CÓPIA, mas sim uma REFERÊNCIA/VIEW á coluna do dataframe

# %%
# fazendo uma cópia
produto_copy_bkp = data['PRODUTO'].copy() # retorna uma cópia da coluna produto do dataframe
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
data['PRODUTO'] = 'Combustível' # atribuindo o valor constante 'Combustível' para todos os index que estão na coluna 'PRODUTO'
data.head(3)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO            ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustível                           127              R$/l
# 1  Combustível                           387              R$/l
# 2  Combustível                           192              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
#
# [3 rows x 21 columns]

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
# para atribuir listas ou series em um dataframe é importante que essa lista tenha a mesma quantidade de elementos que tem o ...
# dataframe original, exemplo:

data.shape
# Out:
# (106823, 21)

# %%
# salvando esses dados em variáveis, você consegue obter o mesmo valor, exemplo:

nrows, ncolumns = data.shape

# numero de linhas, numero de colunas sendo salvos em variáveis respectivamente...

# %%
print(nrows, ncolumns)
# Out:
# 106823 21

# %%
novos_produtos = [f'Produto {i}' for i in range(nrows)] # esse for fará com que o valor 'i' seja imprimido a cada valor que ...
len(novos_produtos) # ele executa, no 'range/intervalo' de 'nrows', que é o tamanho de linhas da coluna
# Out:
# 106823

# %%
# a quantidade de elementos da lista 'novos produtos' é == ao tamanho da lista 'produto' original
data['PRODUTO'] = novos_produtos
data['PRODUTO']
# Out:
# 0              Produto 0
# 1              Produto 1
# 2              Produto 2
# 3              Produto 3
# 4              Produto 4
#                ...
# 106818    Produto 106818
# 106819    Produto 106819
# 106820    Produto 106820
# 106821    Produto 106821
# 106822    Produto 106822
# Name: PRODUTO, Length: 106823, dtype: object

# %%
print(produto_view.head(3))
print('\n')
print(produto_copy_bkp.head(3))
# Out:
# 0    ETANOL HIDRATADO
# 1    ETANOL HIDRATADO
# 2    ETANOL HIDRATADO
# Name: PRODUTO, dtype: object
#
#
# 0    ETANOL HIDRATADO
# 1    ETANOL HIDRATADO
# 2    ETANOL HIDRATADO
# Name: PRODUTO, dtype: object

# %%
# devolvendo o valor inicial á coluna 'PRODUTO' do dataframe

data['PRODUTO'] = produto_copy_bkp
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ ou uma constante a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
# criando uma coluna com um valor constante
data['COLUNA NOVA'] = 'Default'

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                  0.95                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 106818                    2.756                           0
# 106819                    2.451                       0.402
# 106820                    1.998                           0
# 106821                    2.374                       0.165
# 106822                    2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  COLUNA NOVA
# 0                              0.133   5  2004      Default
# 1                              0.115   5  2004      Default
# 2                              0.098   5  2004      Default
# 3                              0.143   5  2004      Default
# 4                              0.082   5  2004      Default
# ...                              ...  ..   ...          ...
# 106818                             0   6  2019      Default
# 106819                         0.164   6  2019      Default
# 106820                             0   6  2019      Default
# 106821                          0.07   6  2019      Default
# 106822                             0   6  2019      Default
#
# [106823 rows x 22 columns]

# %%
data['coluna criada com lista'] = range(data.shape[0]) # range declara que é um intervalo de 'data.shape(0)', ou seja ...
# do tamanho de 'data' começando em 0, conforme foi passado em cerquilha "[]"
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                          0.012                     0.825
# 1                          0.098                     0.763
# 2                          0.070                      0.97
# 3                          0.055                      0.83
# 4                          0.066                     0.941
# ...                          ...                       ...
# 106818                     0.018                     2.756
# 106819                     0.038                     2.451
# 106820                     0.065                     1.998
# 106821                     0.076                     2.374
# 106822                     0.001                     2.518
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.11                     0.4201
# 1                           0.088                     0.5013
# 2                           0.095                     0.5614
# 3                           0.119                     0.5991
# 4                           0.077                     0.7441
# ...                           ...                        ...
# 106818                          0                      2.756
# 106819                      0.402                     1.9842
# 106820                          0                     1.9981
# 106821                      0.165                     2.0179
# 106822                          0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                         0.133   5  2004
# 1                           1.05                         0.115   5  2004
# 2                          1.161                         0.098   5  2004
# 3                        1.22242                         0.143   5  2004
# 4                         1.0317                         0.082   5  2004
# ...                          ...                           ...  ..   ...
# 106818                     2.756                             0   6  2019
# 106819                    2.8661                         0.164   6  2019
# 106820                    1.9981                             0   6  2019
# 106821                    2.5093                          0.07   6  2019
# 106822                    2.5175                             0   6  2019
#
#        COLUNA NOVA  coluna criada com lista
# 0          Default                        0
# 1          Default                        1
# 2          Default                        2
# 3          Default                        3
# 4          Default                        4
# ...            ...                      ...
# 106818     Default                   106818
# 106819     Default                   106819
# 106820     Default                   106820
# 106821     Default                   106821
# 106822     Default                   106822
#
# [106823 rows x 23 columns]

# %%
# lista que não funciona, vamos passar uma lista que não tenha o tamanho da quantidade de index do dataframe

# data['VAI DAR ERRO'] = [1, 2, 3]

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  coluna criada com lista
# 0                         0.133   5  2004     Default                        0
# 1                         0.115   5  2004     Default                        1
# 2                         0.098   5  2004     Default                        2
# 3                         0.143   5  2004     Default                        3
# 4                         0.082   5  2004     Default                        4
#
# [5 rows x 23 columns]

# %%
data['PRECO MEDIO REVENDA (Dólar)'] = data['PREÇO MÉDIO REVENDA'] * 5.4
# estou pegando a coluna 'PREÇO MÉDIO REVENDA' e múltilplicando todos os seus index por 5.4 ...
# e atribuindo esses valores á uma nova coluna, que terá o mesmo tamanho

data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   COLUNA NOVA coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                       0                       6.9552
# 1     Default                       1                       6.2748
# 2     Default                       2                       7.5006
# 3     Default                       3                       6.8148
# 4     Default                       4                       6.3774
#
# [5 rows x 24 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %% [markdown]
# ### 1.4 Selecionando uma ou mais amostras (Indexação)

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma amostra/linha:**

# %%
data.iloc[200]
# Out:
# Unnamed: 0                                       200
# DATA INICIAL                              2004-06-27
# DATA FINAL                                2004-07-03
# REGIÃO                                      NORDESTE
# ESTADO                           RIO GRANDE DO NORTE
# PRODUTO                             ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                     121
# UNIDADE DE MEDIDA                               R$/l
# PREÇO MÉDIO REVENDA                            1.369
# DESVIO PADRÃO REVENDA                          0.074
# PREÇO MÍNIMO REVENDA                            1.19
# PREÇO MÁXIMO REVENDA                            1.59
# MARGEM MÉDIA REVENDA                            0.32
# COEF DE VARIAÇÃO REVENDA                       0.054
# PREÇO MÉDIO DISTRIBUIÇÃO                       1.049
# DESVIO PADRÃO DISTRIBUIÇÃO                     0.116
# PREÇO MÍNIMO DISTRIBUIÇÃO                     0.7869
# PREÇO MÁXIMO DISTRIBUIÇÃO                     1.3143
# COEF DE VARIAÇÃO DISTRIBUIÇÃO                  0.111
# MÊS                                                6
# ANO                                             2004
# COLUNA NOVA                                  Default
# coluna criada com lista                          200
# PRECO MEDIO REVENDA (Dólar)                   7.3926
# Name: 200, dtype: object

# %% [markdown]
# **Selecionando múltiplias amostras/linhas:**

# %%
# selecionando os 10 primeiros indices do dataframe

data.iloc[:10]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
# 5                1.383                  0.132  ...                     0.957
# 6                1.453                  0.218  ...                       1.1
# 7                1.631                  0.158  ...                     1.116
# 8                1.284                  0.130  ...                     0.931
# 9                1.224                  0.141  ...                     0.947
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
# 5                       0.128                    0.5686
# 6                       0.068                    0.7332
# 7                       0.091                    0.9923
# 8                       0.072                    0.7577
# 9                       0.091                    0.5643
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
# 5                       1.35                         0.134   5  2004
# 6                      1.294                         0.062   5  2004
# 7                    1.36183                         0.082   5  2004
# 8                     1.2972                         0.077   5  2004
# 9                     1.3541                         0.096   5  2004
#
#   COLUNA NOVA coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                       0                       6.9552
# 1     Default                       1                       6.2748
# 2     Default                       2                       7.5006
# 3     Default                       3                       6.8148
# 4     Default                       4                       6.3774
# 5     Default                       5                       7.4682
# 6     Default                       6                       7.8462
# 7     Default                       7                       8.8074
# 8     Default                       8                       6.9336
# 9     Default                       9                       6.6096
#
# [10 rows x 24 columns]

# %%
# selecionando um intervalo entre os índices 5 ao 9 (9 incluso)

data.iloc[5:10]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO      ESTADO  \
# 5           5   2004-05-09  2004-05-15  NORDESTE       BAHIA
# 6           6   2004-05-09  2004-05-15  NORDESTE       CEARA
# 7           7   2004-05-09  2004-05-15  NORDESTE    MARANHAO
# 8           8   2004-05-09  2004-05-15  NORDESTE     PARAIBA
# 9           9   2004-05-09  2004-05-15  NORDESTE  PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                1.383                  0.132  ...                     0.957
# 6                1.453                  0.218  ...                       1.1
# 7                1.631                  0.158  ...                     1.116
# 8                1.284                  0.130  ...                     0.931
# 9                1.224                  0.141  ...                     0.947
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                       0.128                    0.5686
# 6                       0.068                    0.7332
# 7                       0.091                    0.9923
# 8                       0.072                    0.7577
# 9                       0.091                    0.5643
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5                       1.35                         0.134   5  2004
# 6                      1.294                         0.062   5  2004
# 7                    1.36183                         0.082   5  2004
# 8                     1.2972                         0.077   5  2004
# 9                     1.3541                         0.096   5  2004
#
#   COLUNA NOVA coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 5     Default                       5                       7.4682
# 6     Default                       6                       7.8462
# 7     Default                       7                       8.8074
# 8     Default                       8                       6.9336
# 9     Default                       9                       6.6096
#
# [5 rows x 24 columns]

# %%
# escolhendo índices específicos para mostrar, como: valores 4, 8, 12, 16, 20

data.iloc[[4, 8, 12, 16, 20]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO          ESTADO  \
# 4            4   2004-05-09  2004-05-15  NORDESTE         ALAGOAS
# 8            8   2004-05-09  2004-05-15  NORDESTE         PARAIBA
# 12          12   2004-05-09  2004-05-15  NORDESTE         SERGIPE
# 16          16   2004-05-09  2004-05-15     NORTE            PARA
# 20          20   2004-05-09  2004-05-15   SUDESTE  ESPIRITO SANTO
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 4   ETANOL HIDRATADO                           103              R$/l
# 8   ETANOL HIDRATADO                           125              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 16  ETANOL HIDRATADO                           104              R$/l
# 20  ETANOL HIDRATADO                           306              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 4                 1.181                  0.078  ...                     0.941
# 8                 1.284                  0.130  ...                     0.931
# 12                1.301                  0.109  ...                      0.98
# 16                1.914                  0.246  ...                     1.378
# 20                1.148                  0.116  ...                     0.881
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 4                        0.077                    0.7441
# 8                        0.072                    0.7577
# 12                       0.052                    0.8267
# 16                       0.237                    0.7564
# 20                       0.095                    0.6259
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 4                      1.0317                         0.082   5  2004
# 8                      1.2972                         0.077   5  2004
# 12                     1.1059                         0.053   5  2004
# 16                     1.8908                         0.172   5  2004
# 20                     1.1381                         0.108   5  2004
#
#    COLUNA NOVA coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 4      Default                       4                       6.3774
# 8      Default                       8                       6.9336
# 12     Default                      12                       7.0254
# 16     Default                      16                      10.3356
# 20     Default                      20                       6.1992
#
# [5 rows x 24 columns]

# %%
# selecionando as observações de índices em ordem aleatória/não crescente

data.iloc[[12, 1, 87, 33]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO   ESTADO  \
# 12          12   2004-05-09  2004-05-15      NORDESTE  SERGIPE
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE    GOIAS
# 87          87   2004-05-30  2004-06-05      NORDESTE    CEARA
# 33          33   2004-05-16  2004-05-22      NORDESTE    CEARA
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 12  ETANOL HIDRATADO                            57              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 87  ETANOL HIDRATADO                           269              R$/l
# 33  ETANOL HIDRATADO                           277              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 12                1.301                  0.109  ...                      0.98
# 1                 1.162                  0.114  ...                     0.763
# 87                1.442                  0.206  ...                     1.109
# 33                1.451                  0.219  ...                     1.104
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 12                       0.052                    0.8267
# 1                        0.088                    0.5013
# 87                        0.07                   0.85727
# 33                        0.06                      0.92
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 12                     1.1059                         0.053   5  2004
# 1                        1.05                         0.115   5  2004
# 87                       1.27                         0.063   5  2004
# 33                       1.27                         0.054   5  2004
#
#    COLUNA NOVA coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 12     Default                      12                       7.0254
# 1      Default                       1                       6.2748
# 87     Default                      87                       7.7868
# 33     Default                      33                       7.8354
#
# [4 rows x 24 columns]

# %%
# retornando o valor do índice 1, coluna 4 ('ESTADO')

data.iloc[1, 4]
# Out:
# 'GOIAS'

# %%
# e assim por diante!

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna a linha de indice 0 ==> usando o iloc

pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# usando o loc

pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# NÃO FUNCIONA ==> usando o iloc para pesquisar indices com rótulos

## pesquisa_de_satisfacao.iloc['XboxOne']

# %%
# NÃO FUNCIONA ==> usando o loc para pesquisar indices com números

## pesquisa_de_satisfacao.loc[1]

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# quero acessar de maneiras diferentes as avaliações ruins de 'Playstation4'
# USANDO ILOC

pesquisa_de_satisfacao.iloc[1, 1]
# Out:
# 2

# %%
#USANDO LOC

# %%
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# 2

# %%
# passando listas de índices rotulados

pesquisa_de_satisfacao.loc[['Playstation4', 'Switch']]
# Out:
#               bom  ruim  pessimo
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorne todas as linhas e apenas as colunas com rótulos 'bom' e 'pessimo'
# posso fazer de duas maneiras, sendo elas, sem LOC:

pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
# com LOC

pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]

# USANDO ':' para definir um intervalo, quando não tem valor nem antes e nem depois, significa que estou pedindo um...
# intervalo do início ao fim
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
# usando ILOC

pesquisa_de_satisfacao.iloc[:,[0, 2]]

# USANDO ':' para definir um intervalo, quando não tem valor nem antes e nem depois, significa que estou pedindo um...
# intervalo do início ao fim
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
data.head(2)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO            ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
#
#   COLUNA NOVA coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                       0                       6.9552
# 1     Default                       1                       6.2748
#
# [2 rows x 24 columns]

# %%
data.iloc[[1, 4, 7], [8]]
# Out:
#    PREÇO MÉDIO REVENDA
# 1                1.162
# 4                1.181
# 7                1.631

# %%
# NO DATAFRAME 'DATA', VOU PROCURAR PELO PREÇO DE MÉDIO DE REVENDA DOS INDÍCES '1, 4, 7' USANDO LOC E ILOC

data.loc[[1, 4, 7], ['PREÇO MÉDIO REVENDA']]
# Out:
#    PREÇO MÉDIO REVENDA
# 1                1.162
# 4                1.181
# 7                1.631

# %%
# FAZENDO O MESMO ESTILO DE BUSCA COM INTERVALO: ESTADO DOS PRIMEIROS 4 ÍNDICES

data.loc[:3, ['ESTADO']]
# Out:
#                ESTADO
# 0    DISTRITO FEDERAL
# 1               GOIAS
# 2         MATO GROSSO
# 3  MATO GROSSO DO SUL

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
data.head(3)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO            ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
#
#   COLUNA NOVA coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                       0                       6.9552
# 1     Default                       1                       6.2748
# 2     Default                       2                       7.5006
#
# [3 rows x 24 columns]

# %%
# deleta/remove a coluna que foi passada, que no caso, 'Unnamed: 0'. 

del data['Unnamed: 0']

# %%
data.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                  0.016                  1.19  ...                     0.825
# 1                  0.114                  0.89  ...                     0.763
# 2                  0.097                  1.18  ...                      0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                     0.4201
# 1                      0.088                     0.5013
# 2                      0.095                     0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
#
#   COLUNA NOVA  coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                        0                       6.9552
# 1     Default                        1                       6.2748
# 2     Default                        2                       7.5006
#
# [3 rows x 23 columns]

# %%
data.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                  0.016                  1.19  ...                     0.825
# 1                  0.114                  0.89  ...                     0.763
# 2                  0.097                  1.18  ...                      0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                     0.4201
# 1                      0.088                     0.5013
# 2                      0.095                     0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
#
#   COLUNA NOVA  coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                        0                       6.9552
# 1     Default                        1                       6.2748
# 2     Default                        2                       7.5006
#
# [3 rows x 23 columns]

# %% [markdown]
# <br>
#
# Removendo as colunas fícticias criadas ao decorrer dos estudos.
#
# <br>

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False)

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv')

# %%
data.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                  0.016                  1.19  ...                     0.825
# 1                  0.114                  0.89  ...                     0.763
# 2                  0.097                  1.18  ...                      0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                     0.4201
# 1                      0.088                     0.5013
# 2                      0.095                     0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
#
#   COLUNA NOVA  coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                        0                       6.9552
# 1     Default                        1                       6.2748
# 2     Default                        2                       7.5006
#
# [3 rows x 23 columns]

# %%
# usando a função 'unique' para descobrir quais são os valores únicos dentro de 'ESTADO' e salvando em um array 'estados'.

estados = data.ESTADO.unique()

# %%
estados
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (observações) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
# compara elemento a elemento da series, retornando outra sderies de booleans

data['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
# salvando a series em uma variável

selecao = data.ESTADO == 'SAO PAULO'

type(selecao)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
# fazendo isso, fará com que mostre apenas as linhas cujo resultado booleano seja 'True', conforme a comparação acima.

data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                         0.4271                    1.4123
# 50                        0.43204                    0.9724
# 77                        0.34951                     1.412
# 104                        0.3398                    1.0669
# 131                       0.47797                    1.0669
# ...                           ...                       ...
# 106724                     2.8599                    3.3481
# 106751                      2.885                     3.491
# 106778                       3.52                    4.0892
# 106805                      40.19                        72
# 106821                     2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 23                             0.098   5  2004     Default
# 50                             0.087   5  2004     Default
# 77                             0.103   5  2004     Default
# 104                            0.112   5  2004     Default
# 131                            0.104   6  2004     Default
# ...                              ...  ..   ...         ...
# 106724                         0.032   6  2019     Default
# 106751                         0.036   6  2019     Default
# 106778                         0.026   6  2019     Default
# 106805                         0.103   6  2019     Default
# 106821                          0.07   6  2019     Default
#
#         coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 23                           23                       4.1472
# 50                           50                       4.1364
# 77                           77                       4.4442
# 104                         104                       4.7898
# 131                         131                       4.8276
# ...                         ...                          ...
# 106724                   106724                      18.6192
# 106751                   106751                      19.2996
# 106778                   106778                      22.3668
# 106805                   106805                     361.2222
# 106821                   106821                      16.3080
#
# [4263 rows x 23 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
data.loc[selecao].head(2)
# Out:
#    DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#     NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                          4047              R$/l                0.768
# 50                          4066              R$/l                0.766
#
#     DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                  0.085                  0.59  ...
# 50                  0.083                  0.59  ...
#
#     PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                      0.57                      0.056
# 50                     0.576                       0.05
#
#     PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                     0.4271                    1.4123
# 50                    0.43204                    0.9724
#
#    COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 23                         0.098   5  2004     Default
# 50                         0.087   5  2004     Default
#
#     coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 23                       23                       4.1472
# 50                       50                       4.1364
#
# [2 rows x 23 columns]

# %%
data.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                  0.016                  1.19  ...                     0.825
# 1                  0.114                  0.89  ...                     0.763
# 2                  0.097                  1.18  ...                      0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                     0.4201
# 1                      0.088                     0.5013
# 2                      0.095                     0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
#
#   COLUNA NOVA  coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                        0                       6.9552
# 1     Default                        1                       6.2748
# 2     Default                        2                       7.5006
#
# [3 rows x 23 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.query('ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                         0.4271                    1.4123
# 50                        0.43204                    0.9724
# 77                        0.34951                     1.412
# 104                        0.3398                    1.0669
# 131                       0.47797                    1.0669
# ...                           ...                       ...
# 106724                     2.8599                    3.3481
# 106751                      2.885                     3.491
# 106778                       3.52                    4.0892
# 106805                      40.19                        72
# 106821                     2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 23                             0.098   5  2004     Default
# 50                             0.087   5  2004     Default
# 77                             0.103   5  2004     Default
# 104                            0.112   5  2004     Default
# 131                            0.104   6  2004     Default
# ...                              ...  ..   ...         ...
# 106724                         0.032   6  2019     Default
# 106751                         0.036   6  2019     Default
# 106778                         0.026   6  2019     Default
# 106805                         0.103   6  2019     Default
# 106821                          0.07   6  2019     Default
#
#         coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 23                           23                       4.1472
# 50                           50                       4.1364
# 77                           77                       4.4442
# 104                         104                       4.7898
# 131                         131                       4.8276
# ...                         ...                          ...
# 106724                   106724                      18.6192
# 106751                   106751                      19.2996
# 106778                   106778                      22.3668
# 106805                   106805                     361.2222
# 106821                   106821                      16.3080
#
# [4263 rows x 23 columns]

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análises feitas para os postos de São Paulo.

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"')

# %%
postos_sp.head(4)
# Out:
#     DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23    2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50    2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77    2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                           4047              R$/l                0.768
# 50                           4066              R$/l                0.766
# 77                           4077              R$/l                0.823
# 104                          4073              R$/l                0.887
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                   0.085                 0.590  ...
# 50                   0.083                 0.590  ...
# 77                   0.071                 0.620  ...
# 104                  0.075                 0.639  ...
#
#      PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                       0.57                      0.056
# 50                      0.576                       0.05
# 77                      0.614                      0.063
# 104                     0.671                      0.075
#
#      PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                      0.4271                    1.4123
# 50                     0.43204                    0.9724
# 77                     0.34951                     1.412
# 104                     0.3398                    1.0669
#
#     COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 23                          0.098   5  2004     Default
# 50                          0.087   5  2004     Default
# 77                          0.103   5  2004     Default
# 104                         0.112   5  2004     Default
#
#      coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 23                        23                       4.1472
# 50                        50                       4.1364
# 77                        77                       4.4442
# 104                      104                       4.7898
#
# [4 rows x 23 columns]

# %% [markdown]
# ## Resetando os índices

# %%
# usando 'drop=True' para jogar fora os índices originais, para não ter uma coluna chamada 'indice' no dataframe ...
# depois de ter usado a função 'reset_index'.

postos_sp.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     0.085                 0.590  ...
# 1                     0.083                 0.590  ...
# 2                     0.071                 0.620  ...
# 3                     0.075                 0.639  ...
# 4                     0.071                 0.669  ...
# ...                     ...                   ...  ...
# 4258                  0.156                 3.099  ...
# 4259                  0.169                 3.199  ...
# 4260                  0.183                 3.769  ...
# 4261                  6.100                50.000  ...
# 4262                  0.229                 2.699  ...
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.57                      0.056
# 1                        0.576                       0.05
# 2                        0.614                      0.063
# 3                        0.671                      0.075
# 4                        0.689                      0.072
# ...                        ...                        ...
# 4258                     3.047                      0.097
# 4259                     3.123                      0.111
# 4260                     3.713                      0.097
# 4261                    49.214                      5.071
# 4262                     2.374                      0.165
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                        0.4271                    1.4123
# 1                       0.43204                    0.9724
# 2                       0.34951                     1.412
# 3                        0.3398                    1.0669
# 4                       0.47797                    1.0669
# ...                         ...                       ...
# 4258                     2.8599                    3.3481
# 4259                      2.885                     3.491
# 4260                       3.52                    4.0892
# 4261                      40.19                        72
# 4262                     2.0179                    2.5093
#
#      COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 0                            0.098   5  2004     Default
# 1                            0.087   5  2004     Default
# 2                            0.103   5  2004     Default
# 3                            0.112   5  2004     Default
# 4                            0.104   6  2004     Default
# ...                            ...  ..   ...         ...
# 4258                         0.032   6  2019     Default
# 4259                         0.036   6  2019     Default
# 4260                         0.026   6  2019     Default
# 4261                         0.103   6  2019     Default
# 4262                          0.07   6  2019     Default
#
#       coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                          23                       4.1472
# 1                          50                       4.1364
# 2                          77                       4.4442
# 3                         104                       4.7898
# 4                         131                       4.8276
# ...                       ...                          ...
# 4258                   106724                      18.6192
# 4259                   106751                      19.2996
# 4260                   106778                      22.3668
# 4261                   106805                     361.2222
# 4262                   106821                      16.3080
#
# [4263 rows x 23 columns]

# %% [markdown]
# *AGORA FAZENDO A CHAMADA DA VARIAVEL...*

# %%
postos_sp.head(3)
# Out:
#    DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#     NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                          4047              R$/l                0.768
# 50                          4066              R$/l                0.766
# 77                          4077              R$/l                0.823
#
#     DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                  0.085                  0.59  ...
# 50                  0.083                  0.59  ...
# 77                  0.071                  0.62  ...
#
#     PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                      0.57                      0.056
# 50                     0.576                       0.05
# 77                     0.614                      0.063
#
#     PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                     0.4271                    1.4123
# 50                    0.43204                    0.9724
# 77                    0.34951                     1.412
#
#    COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 23                         0.098   5  2004     Default
# 50                         0.087   5  2004     Default
# 77                         0.103   5  2004     Default
#
#     coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 23                       23                       4.1472
# 50                       50                       4.1364
# 77                       77                       4.4442
#
# [3 rows x 23 columns]

# %%
# isso porque não usei o parâmetro 'implace=True', que faz a alteração na prórpia variável e não apenas gera uma cópia ...
# para execução.

postos_sp.reset_index(drop=True, inplace=True)

postos_sp.head(3)
# Out:
#   DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                          4047              R$/l                0.768
# 1                          4066              R$/l                0.766
# 2                          4077              R$/l                0.823
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                  0.085                  0.59  ...                      0.57
# 1                  0.083                  0.59  ...                     0.576
# 2                  0.071                  0.62  ...                     0.614
#
#   DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                      0.056                     0.4271
# 1                       0.05                    0.43204
# 2                      0.063                    0.34951
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    1.4123                         0.098   5  2004
# 1                    0.9724                         0.087   5  2004
# 2                     1.412                         0.103   5  2004
#
#   COLUNA NOVA  coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                       23                       4.1472
# 1     Default                       50                       4.1364
# 2     Default                       77                       4.4442
#
# [3 rows x 23 columns]

# %%
# ALTERNATIVA COMUM USANDO QUERY

postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True)

postos_sp.head()
# Out:
#   DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                          4047              R$/l                0.768
# 1                          4066              R$/l                0.766
# 2                          4077              R$/l                0.823
# 3                          4073              R$/l                0.887
# 4                          4082              R$/l                0.894
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                  0.085                 0.590  ...                      0.57
# 1                  0.083                 0.590  ...                     0.576
# 2                  0.071                 0.620  ...                     0.614
# 3                  0.075                 0.639  ...                     0.671
# 4                  0.071                 0.669  ...                     0.689
#
#   DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                      0.056                     0.4271
# 1                       0.05                    0.43204
# 2                      0.063                    0.34951
# 3                      0.075                     0.3398
# 4                      0.072                    0.47797
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    1.4123                         0.098   5  2004
# 1                    0.9724                         0.087   5  2004
# 2                     1.412                         0.103   5  2004
# 3                    1.0669                         0.112   5  2004
# 4                    1.0669                         0.104   6  2004
#
#   COLUNA NOVA  coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                       23                       4.1472
# 1     Default                       50                       4.1364
# 2     Default                       77                       4.4442
# 3     Default                      104                       4.7898
# 4     Default                      131                       4.8276
#
# [5 rows x 23 columns]

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 0                         0.133   5  2004     Default
# 1                         0.115   5  2004     Default
# 2                         0.098   5  2004     Default
# 3                         0.143   5  2004     Default
# 4                         0.082   5  2004     Default
#
#    coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                        0                       6.9552
# 1                        1                       6.2748
# 2                        2                       7.5006
# 3                        3                       6.8148
# 4                        4                       6.3774
#
# [5 rows x 23 columns]

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 0                         0.133   5  2004     Default
# 1                         0.115   5  2004     Default
# 2                         0.098   5  2004     Default
# 3                         0.143   5  2004     Default
# 4                         0.082   5  2004     Default
#
#    coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                        0                       6.9552
# 1                        1                       6.2748
# 2                        2                       7.5006
# 3                        3                       6.8148
# 4                        4                       6.3774
#
# [5 rows x 23 columns]

# %%
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] > 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
preco_medio_rj = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)

data[preco_medio_rj].reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 0      2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 1      2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2      2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 3      2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 4      2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...           ...         ...      ...             ...               ...
# 3049   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 3050   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 3051   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 3052   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 3053   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              881              R$/l                2.028
# 1                              889              R$/l                2.125
# 2                              902              R$/l                2.163
# 3                              898              R$/l                2.166
# 4                              890              R$/l                2.172
# ...                            ...               ...                  ...
# 3049                           212              R$/l                3.569
# 3050                           335              R$/l                3.697
# 3051                           422              R$/l                4.928
# 3052                           221           R$/13Kg               65.010
# 3053                           124             R$/m3                3.111
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     0.148                 1.589  ...
# 1                     0.149                 1.779  ...
# 2                     0.138                 1.799  ...
# 3                     0.146                 1.760  ...
# 4                     0.143                 1.789  ...
# ...                     ...                   ...  ...
# 3049                  0.166                 3.179  ...
# 3050                  0.187                 3.279  ...
# 3051                  0.165                 4.599  ...
# 3052                  5.812                50.000  ...
# 3053                  0.260                 2.799  ...
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                        1.806                       0.11
# 1                        1.839                      0.117
# 2                        1.895                      0.134
# 3                        1.935                       0.14
# 4                        1.963                      0.133
# ...                        ...                        ...
# 3049                     3.102                      0.119
# 3050                     3.197                      0.127
# 3051                      4.39                      0.097
# 3052                    47.535                      3.934
# 3053                     2.404                      0.174
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          1.31                    2.1358
# 1                         1.438                    2.2801
# 2                          1.43                    2.3454
# 3                         1.438                    2.2925
# 4                         1.438                    2.2513
# ...                         ...                       ...
# 3049                      2.886                    3.5162
# 3050                     2.9772                    3.5388
# 3051                        4.2                     4.618
# 3052                         39                      58.2
# 3053                      2.126                    2.7909
#
#      COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 0                            0.061   2  2006     Default
# 1                            0.064   3  2006     Default
# 2                            0.071   3  2006     Default
# 3                            0.072   3  2006     Default
# 4                            0.068   3  2006     Default
# ...                            ...  ..   ...         ...
# 3049                         0.038   6  2019     Default
# 3050                          0.04   6  2019     Default
# 3051                         0.022   6  2019     Default
# 3052                         0.083   6  2019     Default
# 3053                         0.072   6  2019     Default
#
#       coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                        2501                      10.9512
# 1                        2528                      11.4750
# 2                        2555                      11.6802
# 3                        2582                      11.6964
# 4                        2609                      11.7288
# ...                       ...                          ...
# 3049                   106718                      19.2726
# 3050                   106745                      19.9638
# 3051                   106772                      26.6112
# 3052                   106799                     351.0540
# 3053                   106817                      16.7994
#
# [3054 rows x 23 columns]

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro **E/AND/&** o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %%
data.query('ESTADO == "RIO DE JANEIRO" or ESTADO == "SAO PAULO"').reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 1      2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 3      2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 4      2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...           ...         ...      ...             ...               ...
# 8521   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 8522   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 8523   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 8524   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 8525   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              952              R$/l                1.098
# 1                             4047              R$/l                0.768
# 2                              948              R$/l                1.092
# 3                             4066              R$/l                0.766
# 4                              973              R$/l                1.103
# ...                            ...               ...                  ...
# 8521                          1644              R$/l                4.142
# 8522                           221           R$/13Kg               65.010
# 8523                          1017           R$/13Kg               66.893
# 8524                           124             R$/m3                3.111
# 8525                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     0.154                 0.740  ...
# 1                     0.085                 0.590  ...
# 2                     0.157                 0.740  ...
# 3                     0.083                 0.590  ...
# 4                     0.140                 0.770  ...
# ...                     ...                   ...  ...
# 8521                  0.183                 3.769  ...
# 8522                  5.812                50.000  ...
# 8523                  6.100                50.000  ...
# 8524                  0.260                 2.799  ...
# 8525                  0.229                 2.699  ...
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                        0.786                      0.173
# 1                         0.57                      0.056
# 2                        0.808                      0.175
# 3                        0.576                       0.05
# 4                        0.822                      0.166
# ...                        ...                        ...
# 8521                     3.713                      0.097
# 8522                    47.535                      3.934
# 8523                    49.214                      5.071
# 8524                     2.404                      0.174
# 8525                     2.374                      0.165
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.326                     1.263
# 1                        0.4271                    1.4123
# 2                        0.3257                    1.2921
# 3                       0.43204                    0.9724
# 4                       0.38909                    1.1859
# ...                         ...                       ...
# 8521                       3.52                    4.0892
# 8522                         39                      58.2
# 8523                      40.19                        72
# 8524                      2.126                    2.7909
# 8525                     2.0179                    2.5093
#
#      COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 0                             0.22   5  2004     Default
# 1                            0.098   5  2004     Default
# 2                            0.217   5  2004     Default
# 3                            0.087   5  2004     Default
# 4                            0.202   5  2004     Default
# ...                            ...  ..   ...         ...
# 8521                         0.026   6  2019     Default
# 8522                         0.083   6  2019     Default
# 8523                         0.103   6  2019     Default
# 8524                         0.072   6  2019     Default
# 8525                          0.07   6  2019     Default
#
#       coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                          22                       5.9292
# 1                          23                       4.1472
# 2                          49                       5.8968
# 3                          50                       4.1364
# 4                          76                       5.9562
# ...                       ...                          ...
# 8521                   106778                      22.3668
# 8522                   106799                     351.0540
# 8523                   106805                     361.2222
# 8524                   106817                      16.7994
# 8525                   106821                      16.3080
#
# [8526 rows x 23 columns]

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (observação a observação) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (observação a observação) do DataFrame, quais são os registros cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, se tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[selecao_1]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 49                               948              R$/l                1.092
# 76                               973              R$/l                1.103
# 103                              955              R$/l                1.149
# 130                              966              R$/l                1.165
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 22                      0.154                 0.740  ...
# 49                      0.157                 0.740  ...
# 76                      0.140                 0.770  ...
# 103                     0.156                 0.799  ...
# 130                     0.154                 0.830  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                         0.786                      0.173
# 49                         0.808                      0.175
# 76                         0.822                      0.166
# 103                        0.849                      0.188
# 130                        0.911                      0.198
# ...                          ...                        ...
# 106718                     3.102                      0.119
# 106745                     3.197                      0.127
# 106772                      4.39                      0.097
# 106799                    47.535                      3.934
# 106817                     2.404                      0.174
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                          0.326                     1.263
# 49                         0.3257                    1.2921
# 76                        0.38909                    1.1859
# 103                        0.3453                    1.3667
# 130                           0.4                    1.3667
# ...                           ...                       ...
# 106718                      2.886                    3.5162
# 106745                     2.9772                    3.5388
# 106772                        4.2                     4.618
# 106799                         39                      58.2
# 106817                      2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 22                              0.22   5  2004     Default
# 49                             0.217   5  2004     Default
# 76                             0.202   5  2004     Default
# 103                            0.221   5  2004     Default
# 130                            0.217   6  2004     Default
# ...                              ...  ..   ...         ...
# 106718                         0.038   6  2019     Default
# 106745                          0.04   6  2019     Default
# 106772                         0.022   6  2019     Default
# 106799                         0.083   6  2019     Default
# 106817                         0.072   6  2019     Default
#
#         coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 22                           22                       5.9292
# 49                           49                       5.8968
# 76                           76                       5.9562
# 103                         103                       6.2046
# 130                         130                       6.2910
# ...                         ...                          ...
# 106718                   106718                      19.2726
# 106745                   106745                      19.9638
# 106772                   106772                      26.6112
# 106799                   106799                     351.0540
# 106817                   106817                      16.7994
#
# [4263 rows x 23 columns]

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
postos_rj[selecao_2].head(3).reset_index(drop=True)
# Out:
#   DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 0   2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 1   2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2   2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           881              R$/l                2.028
# 1                           889              R$/l                2.125
# 2                           902              R$/l                2.163
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                  0.148                 1.589  ...                     1.806
# 1                  0.149                 1.779  ...                     1.839
# 2                  0.138                 1.799  ...                     1.895
#
#   DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                       1.31
# 1                      0.117                      1.438
# 2                      0.134                       1.43
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    2.1358                         0.061   2  2006
# 1                    2.2801                         0.064   3  2006
# 2                    2.3454                         0.071   3  2006
#
#   COLUNA NOVA  coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0     Default                     2501                      10.9512
# 1     Default                     2528                      11.4750
# 2     Default                     2555                      11.6802
#
# [3 rows x 23 columns]

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
selecao_sp_rj= (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')

# %%
selecao_gas_comum = data['PRODUTO'] == 'GASOLINA COMUM'

# %%
selecao_acima_de_2 = data['PREÇO MÉDIO REVENDA'] > 2

# %%
selecao_final = selecao_sp_rj & selecao_gas_comum & selecao_acima_de_2

# %%
data[selecao_final]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12113                   0.113                 1.700  ...
# 12140                   0.108                 1.700  ...
# 12167                   0.111                 1.730  ...
# 12194                   0.107                 1.760  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                      1.791                      0.047
# 12113                      1.788                      0.049
# 12140                       1.79                      0.046
# 12167                      1.802                      0.055
# 12194                      1.816                      0.054
# ...                          ...                        ...
# 106479                     3.785                      0.096
# 106623                     4.383                        0.1
# 106629                     3.725                      0.096
# 106772                      4.39                      0.097
# 106778                     3.713                      0.097
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                      1.6363                    1.9594
# 12113                      1.5943                   1.99651
# 12140                     1.63596                    2.2137
# 12167                        1.64                   2.21425
# 12194                        1.64                   2.32425
# ...                           ...                       ...
# 106479                       3.52                    4.1007
# 106623                     4.1972                    4.6239
# 106629                      3.502                    4.0892
# 106772                        4.2                     4.618
# 106778                       3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 12086                          0.026   5  2004     Default
# 12113                          0.027   5  2004     Default
# 12140                          0.026   5  2004     Default
# 12167                          0.031   5  2004     Default
# 12194                           0.03   6  2004     Default
# ...                              ...  ..   ...         ...
# 106479                         0.025   6  2019     Default
# 106623                         0.023   6  2019     Default
# 106629                         0.026   6  2019     Default
# 106772                         0.022   6  2019     Default
# 106778                         0.026   6  2019     Default
#
#         coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 12086                     12086                      11.0430
# 12113                     12113                      11.0160
# 12140                     12140                      11.0268
# 12167                     12167                      11.0862
# 12194                     12194                      11.1402
# ...                         ...                          ...
# 106479                   106479                      22.7340
# 106623                   106623                      26.6058
# 106629                   106629                      22.5072
# 106772                   106772                      26.6112
# 106778                   106778                      22.3668
#
# [1564 rows x 23 columns]

# %% [markdown]
# <br/>
#
# Alternativamente:

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %% [markdown]
# **ALTERNATIVA 1**

# %% [markdown]
# **ALTERNATIVA 2**

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  COLUNA NOVA                    106823 non-null  object
#  21  coluna criada com lista        106823 non-null  int64
#  22  PRECO MEDIO REVENDA (Dólar)    106823 non-null  float64
# dtypes: float64(6), int64(4), object(13)
# memory usage: 18.7+ MB

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do dataset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])

# %%
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  COLUNA NOVA                    106823 non-null  object
#  21  coluna criada com lista        106823 non-null  int64
#  22  PRECO MEDIO REVENDA (Dólar)    106823 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(4), object(11)
# memory usage: 18.7+ MB

# %% [markdown]
# #### **Dados Numéricos**

# %%
# criando uma lista com o nome de todas as colunas que irei fazer a conversão
# e depois passando o valor da lista (nome das colunas) para converter todas de uma vez

# %%
for atributo in ['MARGEM MÉDIA REVENDA','PREÇO MÉDIO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
    data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')
#   converte as colunas com o valor de 'atributo' para numeric e com o parâmetro 'errors' executa uma determinada ...
#   ação em caso de algum erro de conversão, que nesse caso é 'coerce', que basicamente pega um valor que não representa ...
#   um número (string) e converte para um valor vazio (null / nan)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       103423 non-null  float64
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     103423 non-null  float64
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      103423 non-null  float64
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      103423 non-null  float64
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103423 non-null  float64
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  COLUNA NOVA                    106823 non-null  object
#  21  coluna criada com lista        106823 non-null  int64
#  22  PRECO MEDIO REVENDA (Dólar)    106823 non-null  float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(5)
# memory usage: 18.7+ MB

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         NaN                         NaN
# 1958                         NaN                         NaN
# 2012                         NaN                         NaN
# 2497                         NaN                         NaN
# 3199                         NaN                         NaN
# ...                          ...                         ...
# 106664                       NaN                         NaN
# 106666                       NaN                         NaN
# 106811                       NaN                         NaN
# 106813                       NaN                         NaN
# 106815                       NaN                         NaN
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          NaN                        NaN
# 1958                          NaN                        NaN
# 2012                          NaN                        NaN
# 2497                          NaN                        NaN
# 3199                          NaN                        NaN
# ...                           ...                        ...
# 106664                        NaN                        NaN
# 106666                        NaN                        NaN
# 106811                        NaN                        NaN
# 106813                        NaN                        NaN
# 106815                        NaN                        NaN
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  COLUNA NOVA  \
# 1903                              NaN    9  2005      Default
# 1958                              NaN   10  2005      Default
# 2012                              NaN   10  2005      Default
# 2497                              NaN    2  2006      Default
# 3199                              NaN    8  2006      Default
# ...                               ...  ...   ...          ...
# 106664                            NaN    6  2019      Default
# 106666                            NaN    6  2019      Default
# 106811                            NaN    6  2019      Default
# 106813                            NaN    6  2019      Default
# 106815                            NaN    6  2019      Default
#
#         coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 1903                       1903                       9.1476
# 1958                       1958                      10.8000
# 2012                       2012                      12.2958
# 2497                       2497                      11.7828
# 3199                       3199                      12.3390
# ...                         ...                          ...
# 106664                   106664                      18.6030
# 106666                   106666                      16.9128
# 106811                   106811                      17.8146
# 106813                   106813                      19.1592
# 106815                   106815                      17.7660
#
# [3400 rows x 23 columns]

# %%
data[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                           -                          -
# 1958                           -                          -
# 2012                           -                          -
# 2497                           -                          -
# 3199                           -                          -
# ...                          ...                        ...
# 106664                         -                          -
# 106666                         -                          -
# 106811                         -                          -
# 106813                         -                          -
# 106815                         -                          -
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                            -                         -
# 1958                            -                         -
# 2012                            -                         -
# 2497                            -                         -
# 3199                            -                         -
# ...                           ...                       ...
# 106664                          -                         -
# 106666                          -                         -
# 106811                          -                         -
# 106813                          -                         -
# 106815                          -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA NOVA  \
# 1903                               -   9  2005     Default
# 1958                               -  10  2005     Default
# 2012                               -  10  2005     Default
# 2497                               -   2  2006     Default
# 3199                               -   8  2006     Default
# ...                              ...  ..   ...         ...
# 106664                             -   6  2019     Default
# 106666                             -   6  2019     Default
# 106811                             -   6  2019     Default
# 106813                             -   6  2019     Default
# 106815                             -   6  2019     Default
#
#         coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 1903                       1903                       9.1476
# 1958                       1958                      10.8000
# 2012                       2012                      12.2958
# 2497                       2497                      11.7828
# 3199                       3199                      12.3390
# ...                         ...                          ...
# 106664                   106664                      18.6030
# 106666                   106666                      16.9128
# 106811                   106811                      17.8146
# 106813                   106813                      19.1592
# 106815                   106815                      17.7660
#
# [3400 rows x 23 columns]

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
# retorna uma copia do dataframe com todos os valores nan de todas as colunas, com valor de '0', conforme o métudo fillna
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                       0.000
# 106819                     2.451                       0.402
# 106820                     1.998                       0.000
# 106821                     2.374                       0.165
# 106822                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 106818                     2.7560                    2.75600
# 106819                     1.9842                    2.86610
# 106820                     1.9981                    1.99810
# 106821                     2.0179                    2.50930
# 106822                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  COLUNA NOVA  \
# 0                               0.133    5  2004      Default
# 1                               0.115    5  2004      Default
# 2                               0.098    5  2004      Default
# 3                               0.143    5  2004      Default
# 4                               0.082    5  2004      Default
# ...                               ...  ...   ...          ...
# 106818                          0.000    6  2019      Default
# 106819                          0.164    6  2019      Default
# 106820                          0.000    6  2019      Default
# 106821                          0.070    6  2019      Default
# 106822                          0.000    6  2019      Default
#
#         coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                             0                       6.9552
# 1                             1                       6.2748
# 2                             2                       7.5006
# 3                             3                       6.8148
# 4                             4                       6.3774
# ...                         ...                          ...
# 106818                   106818                      19.2996
# 106819                   106819                      18.3654
# 106820                   106820                      15.7248
# 106821                   106821                      16.3080
# 106822                   106822                      19.9638
#
# [106823 rows x 23 columns]

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         0.0                         0.0
# 1958                         0.0                         0.0
# 2012                         0.0                         0.0
# 2497                         0.0                         0.0
# 3199                         0.0                         0.0
# ...                          ...                         ...
# 106664                       0.0                         0.0
# 106666                       0.0                         0.0
# 106811                       0.0                         0.0
# 106813                       0.0                         0.0
# 106815                       0.0                         0.0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          0.0                        0.0
# 1958                          0.0                        0.0
# 2012                          0.0                        0.0
# 2497                          0.0                        0.0
# 3199                          0.0                        0.0
# ...                           ...                        ...
# 106664                        0.0                        0.0
# 106666                        0.0                        0.0
# 106811                        0.0                        0.0
# 106813                        0.0                        0.0
# 106815                        0.0                        0.0
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  COLUNA NOVA  \
# 1903                              0.0    9  2005      Default
# 1958                              0.0   10  2005      Default
# 2012                              0.0   10  2005      Default
# 2497                              0.0    2  2006      Default
# 3199                              0.0    8  2006      Default
# ...                               ...  ...   ...          ...
# 106664                            0.0    6  2019      Default
# 106666                            0.0    6  2019      Default
# 106811                            0.0    6  2019      Default
# 106813                            0.0    6  2019      Default
# 106815                            0.0    6  2019      Default
#
#         coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 1903                       1903                       9.1476
# 1958                       1958                      10.8000
# 2012                       2012                      12.2958
# 2497                       2497                      11.7828
# 3199                       3199                      12.3390
# ...                         ...                          ...
# 106664                   106664                      18.6030
# 106666                   106666                      16.9128
# 106811                   106811                      17.8146
# 106813                   106813                      19.1592
# 106815                   106815                      17.7660
#
# [3400 rows x 23 columns]

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
# remove todos os valores Nan que estão contidos no dataframe
data_pre.dropna(inplace=True)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103392 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  datetime64[ns]
#  1   DATA FINAL                     103392 non-null  datetime64[ns]
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  12  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  18  MÊS                            103392 non-null  int64
#  19  ANO                            103392 non-null  int64
#  20  COLUNA NOVA                    103392 non-null  object
#  21  coluna criada com lista        103392 non-null  int64
#  22  PRECO MEDIO REVENDA (Dólar)    103392 non-null  float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(5)
# memory usage: 18.9+ MB

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %%
data_pre.to_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv', index=False)

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data_final = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv')

# %%
data_final.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                  0.016                  1.19  ...                     0.825
# 1                  0.114                  0.89  ...                     0.763
# 2                  0.097                  1.18  ...                     0.970
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                     0.9666                          0.133    5  2004
# 1                     1.0500                          0.115    5  2004
# 2                     1.1610                          0.098    5  2004
#
#    COLUNA NOVA  coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0      Default                        0                       6.9552
# 1      Default                        1                       6.2748
# 2      Default                        2                       7.5006
#
# [3 rows x 23 columns]

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %%
data_final.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# 50%                 0.115000              2.509000              3.000000
# 75%                 0.190000              3.490000              4.150000
# max                10.748000             90.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
# 25%                0.282000                  0.030000
# 50%                0.383000                  0.042000
# 75%                0.560000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000
#
#        coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# count            103392.000000                103392.000000
# mean              52973.958682                    58.236151
# std               30968.261500                    95.503599
# min                   0.000000                     4.136400
# 25%               25964.750000                    11.194200
# 50%               52661.500000                    14.704200
# 75%               79918.250000                    20.223000
# max              106822.000000                   536.527800

# %%
# para descobrir apenas as estátisticas descritivas de uma coluna em específico

data_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
# salvando em um novo dataframe 'stats' com todas as estatísticas produzidas

stats = data_final.describe()

# %%
stats.head(4)
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
#
#        coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# count            103392.000000                103392.000000
# mean              52973.958682                    58.236151
# std               30968.261500                    95.503599
# min                   0.000000                     4.136400

# %%
# mostrando algumas colunas, fazendo uma lista com os nomes das listas

stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÍNIMO REVENDA', 'PREÇO MÁXIMO REVENDA']]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA
# count        103392.000000         103392.000000         103392.000000
# mean             10.784472              9.334931             12.458686
# std              17.685852             15.024383             20.801190
# min               0.766000              0.590000              0.999000
# 25%               2.073000              1.900000              2.330000
# 50%               2.723000              2.509000              3.000000
# 75%               3.745000              3.490000              4.150000
# max              99.357000             90.000000            120.000000

# %%
# ou...

nomes = ['PREÇO MÉDIO REVENDA', 'PREÇO MÍNIMO REVENDA', 'PREÇO MÁXIMO REVENDA']
stats[(nomes)]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA
# count        103392.000000         103392.000000         103392.000000
# mean             10.784472              9.334931             12.458686
# std              17.685852             15.024383             20.801190
# min               0.766000              0.590000              0.999000
# 25%               2.073000              1.900000              2.330000
# 50%               2.723000              2.509000              3.000000
# 75%               3.745000              3.490000              4.150000
# max              99.357000             90.000000            120.000000

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
# usando loc para acessar estatísticas de índices rotulados, como: "mean", "min" e "max" da função 'describe()'
# dentro da coluna 'PREÇO MÉDIO REVENDA'

stats.loc[['min', 'max', 'mean'], 'PREÇO MÉDIO REVENDA']

# é necessário usar a função "LOC[]", porque estamos em buscas de índices rotulados e não númericos.
# Out:
# min      0.766000
# max     99.357000
# mean    10.784472
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats.loc[['min', 'max']]
# Out:
#      NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# min                           1.0                0.766                  0.000
# max                        4167.0               99.357                 10.748
#
#      PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# min                  0.59                 0.999                 0.001
# max                 90.00               120.000                36.847
#
#      COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# min                     0.000                     0.506
# max                     0.262                    83.137
#
#      DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# min                       0.000                     0.3257
# max                      18.385                    83.0000
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO   MÊS     ANO  \
# min                     0.5992                           0.00   1.0  2004.0
# max                    94.5000                           0.78  12.0  2019.0
#
#      coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# min                      0.0                       4.1364
# max                 106822.0                     536.5278

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.110
# 1                     0.763                       0.088
# 2                     0.970                       0.095
# 3                     0.830                       0.119
# 4                     0.941                       0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.96660
# 1                     0.5013                    1.05000
# 2                     0.5614                    1.16100
# 3                     0.5991                    1.22242
# 4                     0.7441                    1.03170
#
#    COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  COLUNA NOVA  \
# 0                          0.133    5  2004      Default
# 1                          0.115    5  2004      Default
# 2                          0.098    5  2004      Default
# 3                          0.143    5  2004      Default
# 4                          0.082    5  2004      Default
#
#    coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                        0                       6.9552
# 1                        1                       6.2748
# 2                        2                       7.5006
# 3                        3                       6.8148
# 4                        4                       6.3774
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
print(data_final['PREÇO MÍNIMO REVENDA'].min())
print(data_final['PREÇO MÍNIMO REVENDA'].mean())
# Out:
# 0.59
# 9.334930555555555

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
media = data_final['PREÇO MÍNIMO REVENDA'].mean()
dv = data_final['PREÇO MÍNIMO REVENDA'].std()

print(f'Média: {media: .2f}\nDesvio Padrão: {dv: .2f}')
# Out:
# Média:  9.33
# Desvio Padrão:  15.02

# %% [markdown]
# #### Quais são os estados considerados?

# %%
# para saber quais são todos os estados presentes dentro da coluna 'ESTADO', utilizaremos a função
# 'unique()'. Ela retorna todos os valores únicos dentro da coluna, na prática...

data_final['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
# mostrar os valores ordenados através do método 'sorted', o método sorted retorna uma cópia de lista ordenana, e não
# modifica a lista original. Para números, ele organiza do < para o >. Em objects ou strings, ele organiza
# do A-Z, em ordem Alfabética.

sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data_final['ESTADO'].value_counts() # retorna uma series contendo a frequência dos valores em ordem crescente
# Out:
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: ESTADO, dtype: int64

# %%
data_final['ESTADO'].value_counts().to_frame() # para transformar essa series em um dataframe
# Out:
#                      ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./imagens/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./imagens/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def nossa_soma(linha):
    return linha.sum() # retornar a soma de todos os valores desta linha

# %%
df[f'SOMA (A, B, C)'] = df.apply(nossa_soma, axis=1)

df
# Out:
#          A   B    C  SOMA (A, B, C)
# Linha 1  1  10  100             111
# Linha 2  2  20  200             222
# Linha 3  3  30  300             333
# Linha 4  4  40  400             444

# %% [markdown]
# <img src='./imagens/apply_axis_1.png' width=250/>

# %%
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
#           A    B     C  SOMA (A, B, C)
# Linha 1   1   10   100             111
# Linha 2   2   20   200             222
# Linha 3   3   30   300             333
# Linha 4   4   40   400             444
# Linha 5  10  100  1000            1110

# %% [markdown]
# <img src='./imagens/apply_axis_0.png' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %%
df['MEDIA(A, B, C)']= df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#           A    B     C  SOMA (A, B, C)  MEDIA(A, B, C)
# Linha 1   1   10   100             111            37.0
# Linha 2   2   20   200             222            74.0
# Linha 3   3   30   300             333           111.0
# Linha 4   4   40   400             444           148.0
# Linha 5  10  100  1000            1110           370.0

# %% [markdown]
# <img src='./imagens/apply_axis_1_mean.png' width=350/>

# %%
df['C * 2'] = df['C'].apply(lambda x: x * 2)
df
# Out:
#           A    B     C  SOMA (A, B, C)  MEDIA(A, B, C)  C * 2
# Linha 1   1   10   100             111            37.0    200
# Linha 2   2   20   200             222            74.0    400
# Linha 3   3   30   300             333           111.0    600
# Linha 4   4   40   400             444           148.0    800
# Linha 5  10  100  1000            1110           370.0   2000

# %%
df['A * 2'] = df['A'] * 2
df
# Out:
#           A    B     C  SOMA (A, B, C)  MEDIA(A, B, C)  C * 2  A * 2
# Linha 1   1   10   100             111            37.0    200      2
# Linha 2   2   20   200             222            74.0    400      4
# Linha 3   3   30   300             333           111.0    600      6
# Linha 4   4   40   400             444           148.0    800      8
# Linha 5  10  100  1000            1110           370.0   2000     20

# %%
df['A * C / B'] = (df['A'] * df['C'] / df['B'])
df
# Out:
#           A    B     C  SOMA (A, B, C)  MEDIA(A, B, C)  C * 2  A * 2  \
# Linha 1   1   10   100             111            37.0    200      2
# Linha 2   2   20   200             222            74.0    400      4
# Linha 3   3   30   300             333           111.0    600      6
# Linha 4   4   40   400             444           148.0    800      8
# Linha 5  10  100  1000            1110           370.0   2000     20
#
#          A * C / B
# Linha 1       10.0
# Linha 2       20.0
# Linha 3       30.0
# Linha 4       40.0
# Linha 5      100.0

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
df.applymap(lambda x: x ** 2)
# Out:
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %%
nomes = pd.Series(['Sabrina', 'Marlon', 'Nicolas', 'Eliana'])
nomes
# Out:
# 0    Sabrina
# 1     Marlon
# 2    Nicolas
# 3     Eliana
# dtype: object

# %%
nomes.map(lambda x: x.upper())
# Out:
# 0    SABRINA
# 1     MARLON
# 2    NICOLAS
# 3     ELIANA
# dtype: object

# %%
nomes.str.lower()
# Out:
# 0    sabrina
# 1     marlon
# 2    nicolas
# 3     eliana
# dtype: object

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 103387               GNV                             7             R$/m3
# 103388               GNV                            23             R$/m3
# 103389               GNV                            24             R$/m3
# 103390               GNV                            52             R$/m3
# 103391               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 103387                3.574                  0.065                 3.499  ...
# 103388                3.401                  0.129                 3.230  ...
# 103389                2.912                  0.190                 2.699  ...
# 103390                3.020                  0.229                 2.699  ...
# 103391                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  COLUNA NOVA  \
# 0                               0.133    5  2004      Default
# 1                               0.115    5  2004      Default
# 2                               0.098    5  2004      Default
# 3                               0.143    5  2004      Default
# 4                               0.082    5  2004      Default
# ...                               ...  ...   ...          ...
# 103387                          0.000    6  2019      Default
# 103388                          0.164    6  2019      Default
# 103389                          0.000    6  2019      Default
# 103390                          0.070    6  2019      Default
# 103391                          0.000    6  2019      Default
#
#         coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                             0                       6.9552
# 1                             1                       6.2748
# 2                             2                       7.5006
# 3                             3                       6.8148
# 4                             4                       6.3774
# ...                         ...                          ...
# 103387                   106818                      19.2996
# 103388                   106819                      18.3654
# 103389                   106820                      15.7248
# 103390                   106821                      16.3080
# 103391                   106822                      19.9638
#
# [103392 rows x 23 columns]

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
grupos = data_final.groupby('REGIÃO')

# %%
grupos.get_group('NORDESTE').head()
# Out:
#   DATA INICIAL  DATA FINAL    REGIÃO    ESTADO           PRODUTO  \
# 4   2004-05-09  2004-05-15  NORDESTE   ALAGOAS  ETANOL HIDRATADO
# 5   2004-05-09  2004-05-15  NORDESTE     BAHIA  ETANOL HIDRATADO
# 6   2004-05-09  2004-05-15  NORDESTE     CEARA  ETANOL HIDRATADO
# 7   2004-05-09  2004-05-15  NORDESTE  MARANHAO  ETANOL HIDRATADO
# 8   2004-05-09  2004-05-15  NORDESTE   PARAIBA  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 4                           103              R$/l                1.181
# 5                           408              R$/l                1.383
# 6                           278              R$/l                1.453
# 7                           105              R$/l                1.631
# 8                           125              R$/l                1.284
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 4                  0.078                 1.050  ...                     0.941
# 5                  0.132                 0.999  ...                     0.957
# 6                  0.218                 1.030  ...                     1.100
# 7                  0.158                 1.350  ...                     1.116
# 8                  0.130                 1.100  ...                     0.931
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 4                       0.077                     0.7441
# 5                       0.128                     0.5686
# 6                       0.068                     0.7332
# 7                       0.091                     0.9923
# 8                       0.072                     0.7577
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 4                    1.03170                          0.082    5  2004
# 5                    1.35000                          0.134    5  2004
# 6                    1.29400                          0.062    5  2004
# 7                    1.36183                          0.082    5  2004
# 8                    1.29720                          0.077    5  2004
#
#    COLUNA NOVA  coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 4      Default                        4                       6.3774
# 5      Default                        5                       7.4682
# 6      Default                        6                       7.8462
# 7      Default                        7                       8.8074
# 8      Default                        8                       6.9336
#
# [5 rows x 23 columns]

# %%
grupos.describe()
# Out:
#              NÚMERO DE POSTOS PESQUISADOS                                      \
#                                     count        mean         std  min    25%
# REGIÃO
# CENTRO OESTE                      14545.0  144.898453  105.699340  1.0   80.0
# NORDESTE                          35788.0  124.721834  113.110808  1.0   41.0
# NORTE                             24000.0   67.835958   52.961342  1.0   31.0
# SUDESTE                           16744.0  726.068024  787.588935  1.0  168.0
# SUL                               12315.0  366.266423  233.276285  1.0  188.0
#
#                                    PREÇO MÉDIO REVENDA             ...  \
#                 50%    75%     max               count       mean  ...
# REGIÃO                                                             ...
# CENTRO OESTE  128.0  192.0   766.0             14545.0  12.299706  ...
# NORDESTE       95.0  169.0   625.0             35788.0   9.558746  ...
# NORTE          53.0   95.0   383.0             24000.0  12.633086  ...
# SUDESTE       412.0  996.0  4167.0             16744.0   9.828218  ...
# SUL           368.0  563.0  1416.0             12315.0  10.254388  ...
#
#              coluna criada com lista           PRECO MEDIO REVENDA (Dólar)  \
#                                  75%       max                       count
# REGIÃO
# CENTRO OESTE                 80299.0  106812.0                     14545.0
# NORDESTE                     79910.5  106822.0                     35788.0
# NORTE                        80343.5  106807.0                     24000.0
# SUDESTE                      79401.5  106821.0                     16744.0
# SUL                          79332.5  106820.0                     12315.0
#
#                                                                         \
#                    mean         std     min      25%      50%      75%
# REGIÃO
# CENTRO OESTE  66.418415  107.734172  5.9238  11.4156  15.1794  20.8494
# NORDESTE      51.617229   86.339781  5.2650  10.6974  14.1696  19.3320
# NORTE         68.218665  106.044398  6.6204  12.8628  16.1838  22.8474
# SUDESTE       53.072378   87.938713  4.1364  10.1358  13.7889  19.2915
# SUL           55.373693   91.280937  4.9788  10.7460  14.0238  19.1862
#
#
#                    max
# REGIÃO
# CENTRO OESTE  536.5278
# NORDESTE      430.0020
# NORTE         471.2580
# SUDESTE       427.6368
# SUL           389.2752
#
# [5 rows x 128 columns]

# %%
grupos.mean()
# Out:
# C:\Users\ADM\AppData\Local\Temp\ipykernel_11772\1316802999.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grupos.mean()
#               NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# REGIÃO
# CENTRO OESTE                    144.898453            12.299706
# NORDESTE                        124.721834             9.558746
# NORTE                            67.835958            12.633086
# SUDESTE                         726.068024             9.828218
# SUL                             366.266423            10.254388
#
#               DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# REGIÃO
# CENTRO OESTE               0.695078             10.610077
# NORDESTE                   0.552230              8.375173
# NORTE                      0.718957             11.410176
# SUDESTE                    0.678608              7.966396
# SUL                        0.729338              8.434376
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE             13.993156              2.438077
# NORDESTE                 10.788018              2.069198
# NORTE                    14.448137              2.221746
# SUDESTE                  11.894671              2.335709
# SUL                      12.391134              2.283191
#
#               COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                  0.042077                  9.861629
# NORDESTE                      0.041247                  7.489549
# NORTE                         0.047480                 10.411340
# SUDESTE                       0.055126                  7.492509
# SUL                           0.047045                  7.971197
#
#               DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                    0.692259                   8.511186
# NORDESTE                        0.514093                   6.563284
# NORTE                           0.442566                   9.505328
# SUDESTE                         0.585445                   6.000720
# SUL                             0.726774                   6.443075
#
#               PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                  11.130478                       0.039288
# NORDESTE                       8.461956                       0.047887
# NORTE                         11.314534                       0.034485
# SUDESTE                        9.330476                       0.060778
# SUL                            9.851008                       0.056162
#
#                    MÊS          ANO  coluna criada com lista  \
# REGIÃO
# CENTRO OESTE  6.483396  2011.773599             52794.848127
# NORDESTE      6.487845  2011.704454             53022.749022
# NORTE         6.488458  2011.812083             52735.865958
# SUDESTE       6.481844  2011.707895             53281.350334
# SUL           6.476736  2011.681608             53089.777913
#
#               PRECO MEDIO REVENDA (Dólar)
# REGIÃO
# CENTRO OESTE                    66.418415
# NORDESTE                        51.617229
# NORTE                           68.218665
# SUDESTE                         53.072378
# SUL                             55.373693

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
grupos = data_final.groupby(['REGIÃO', 'PRODUTO'])

# %%
grupos.mean()
# Out:
# C:\Users\ADM\AppData\Local\Temp\ipykernel_11772\1316802999.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grupos.mean()
#                                NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                    155.514414
#              GASOLINA COMUM                      155.447352
#              GLP                                 202.113944
#              GNV                                   3.759150
#              ÓLEO DIESEL                         131.940332
#              ÓLEO DIESEL S10                      76.054545
# NORDESTE     ETANOL HIDRATADO                    154.143770
#              GASOLINA COMUM                      174.051678
#              GLP                                 127.294072
#              GNV                                  17.498068
#              ÓLEO DIESEL                         135.536185
#              ÓLEO DIESEL S10                      93.857190
# NORTE        ETANOL HIDRATADO                     47.731312
#              GASOLINA COMUM                       77.837665
#              GLP                                  91.767224
#              GNV                                   1.378601
#              ÓLEO DIESEL                          68.135956
#              ÓLEO DIESEL S10                      40.495267
# SUDESTE      ETANOL HIDRATADO                   1038.720115
#              GASOLINA COMUM                     1051.909236
#              GLP                                 757.155881
#              GNV                                  81.839493
#              ÓLEO DIESEL                         771.300955
#              ÓLEO DIESEL S10                     419.743514
# SUL          ETANOL HIDRATADO                    454.889928
#              GASOLINA COMUM                      495.972387
#              GLP                                 487.431498
#              GNV                                  21.242759
#              ÓLEO DIESEL                         364.170348
#              ÓLEO DIESEL S10                     230.283597
#
#                                PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATAD
grupos['PREÇO MÉDIO REVENDA'].mean()
# Out:
# REGIÃO        PRODUTO
# CENTRO OESTE  ETANOL HIDRATADO     2.135670
#               GASOLINA COMUM       3.077476
#               GLP                 48.176747
#               GNV                  1.856312
#               ÓLEO DIESEL          2.481286
#               ÓLEO DIESEL S10      3.294752
# NORDESTE      ETANOL HIDRATADO     2.320266
#               GASOLINA COMUM       3.001887
#               GLP                 41.966090
#               GNV                  1.881722
#               ÓLEO DIESEL          2.346950
#               ÓLEO DIESEL S10      3.041966
# NORTE         ETANOL HIDRATADO     2.511624
#               GASOLINA COMUM       3.149501
#               GLP                 47.065572
#               GNV                  2.084399
#               ÓLEO DIESEL          2.571048
#               ÓLEO DIESEL S10      3.316231
# SUDESTE       ETANOL HIDRATADO     2.163621
#               GASOLINA COMUM       3.000565
#               GLP                 42.081544
#               GNV                  1.716074
#               ÓLEO DIESEL          2.339699
#               ÓLEO DIESEL S10      3.056194
# SUL           ETANOL HIDRATADO     2.268156
#               GASOLINA COMUM       2.972569
#               GLP                 43.490318
#               GNV                  1.865612
#               ÓLEO DIESEL          2.332293
#               ÓLEO DIESEL S10      2.981775
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
grupos['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                                 count       mean        std     min       25%  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  3122.0   2.135670   0.561465   1.162   1.71400
#              GASOLINA COMUM    3134.0   3.077476   0.615290   1.936   2.66725
#              GLP               3098.0  48.176747  15.204045  28.791  37.33300
#              GNV                847.0   1.856312   0.423861   1.097   1.56900
#              ÓLEO DIESEL       3134.0   2.481286   0.626930   1.435   2.03300
#              ÓLEO DIESEL S10   1210.0   3.294752   0.421234   2.305   2.92425
# NORDESTE     ETANOL HIDRATADO  7046.0   2.320266   0.604374   1.181   1.82500
#              GASOLINA COMUM    7063.0   3.001887   0.640696   1.949   2.58400
#              GLP               6410.0  41.966090  12.063743  28.367  33.22875
#              GNV               5176.0   1.881722   0.522996   0.975   1.59600
#              ÓLEO DIESEL       7061.0   2.346950   0.605705   1.313   1.90000
#              ÓLEO DIESEL S10   3032.0   3.041966   0.441550   2.130   2.60000
# NORTE        ETANOL HIDRATADO  5177.0   2.511624   0.646781   1.226   2.03300
#              GASOLINA COMUM    5464.0   3.149501   0.641249   1.995   2.70475
#              GLP               5327.0  47.065572  14.553748  28.086  36.32950
#              GNV                243.0   2.084399   0.622229   1.399   1.39900
#              ÓLEO DIESEL       5465.0   2.571048   0.650994   1.450   2.08600
#              ÓLEO DIESEL S10   2324.0   3.316231   0.529044   2.193   2.88300
# SUDESTE      ETANOL HIDRATADO  3137.0   2.163621   0.651486   0.766   1.69200
#              GASOLINA COMUM    3140.0   3.000565   0.698573   1.888   2.50200
#              GLP               3137.0  42.081544  11.524738  28.026  33.63600
#              GNV               2841.0   1.716074   0.462098   0.996   1.42400
#              ÓLEO DIESEL       3140.0   2.339699   0.588641   1.356   1.87600
#              ÓLEO DIESEL S10   1349.0   3.056194   0.418396   2.180   2.65000
# SUL          ETANOL HIDRATADO  2353.0   2.268156   0.702877   0.922   1.72100
#              GASOLINA COMUM    2354.0   2.972569   0.623557   1.961   2.54300
#              GLP               2343.0  43.490318  11.640755  29.440  34.79250
#              GNV               1899.0   1.865612   0.490703   1.168   1.49900
#              ÓLEO DIESEL       2354.0   2.332293   0.527845   1.374   1.95100
#              ÓLEO DIESEL S10   1012.0   2.981775   0.365470   2.151   2.66300
#
#                                    50%       75%     max
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO   2.0005   2.47900   3.598
#              GASOLINA COMUM     2.8565   3.45975   4.963
#              GLP               42.8385  55.90425  99.357
#              GNV                1.7490   2.16800   3.239
#              ÓLEO DIESEL        2.2465   3.01900   4.162
#              ÓLEO DIESEL S10    3.3540   3.61900   4.200
# NORDESTE     ETANOL HIDRATADO   2.1860   2.67000   3.927
#              GASOLINA COMUM     2.7410   3.42450   4.951
#              GLP               36.8550  48.35100  79.630
#              GNV                1.8005   2.01125   3.811
#              ÓLEO DIESEL        2.0820   2.86700   4.010
#              ÓLEO DIESEL S10    3.0865   3.33800   4.027
# NORTE        ETANOL HIDRATADO   2.3390   2.89600   4.102
#              GASOLINA COMUM     2.9330   3.58475   5.362
#              GLP               42.3110  54.07500  87.270
#              GNV                2.0600   2.65000   3.240
#              ÓLEO DIESEL        2.3390   3.08200   4.774
#              ÓLEO DIESEL S10    3.3155   3.65300   4.878
# SUDESTE      ETANOL HIDRATADO   2.0430   2.56700   4.115
#              GASOLINA COMUM     2.7930   3.45150   5.119
#              GLP               38.2800  49.25900  79.192
#              GNV                1.6630   1.90400   3.399
#              ÓLEO DIESEL        2.0825   2.82500   3.994
#              ÓLEO DIESEL S10    3.0910   3.38600   4.080
# SUL          ETANOL HIDRATADO   2.1130   2.60100   4.287
#              GASOLINA COMUM     2.7315   3.34225   4.953
#              GLP               39.9760  48.73350  72.088
#              GNV                1.7020   2.15950   3.476
#              ÓLEO DIESEL        2.0900   2.78450   3.800
#              ÓLEO DIESEL S10    2.9910   3.25200   3.815

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [None, None, None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum, min])
# Out:
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupo = data_final.groupby('REGIÃO')
grupos

# %%
grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# Out:
#                                   min     max
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO   1.162   3.598
#              GASOLINA COMUM     1.936   4.963
#              GLP               28.791  99.357
#              GNV                1.097   3.239
#              ÓLEO DIESEL        1.435   4.162
#              ÓLEO DIESEL S10    2.305   4.200
# NORDESTE     ETANOL HIDRATADO   1.181   3.927
#              GASOLINA COMUM     1.949   4.951
#              GLP               28.367  79.630
#              GNV                0.975   3.811
#              ÓLEO DIESEL        1.313   4.010
#              ÓLEO DIESEL S10    2.130   4.027
# NORTE        ETANOL HIDRATADO   1.226   4.102
#              GASOLINA COMUM     1.995   5.362
#              GLP               28.086  87.270
#              GNV                1.399   3.240
#              ÓLEO DIESEL        1.450   4.774
#              ÓLEO DIESEL S10    2.193   4.878
# SUDESTE      ETANOL HIDRATADO   0.766   4.115
#              GASOLINA COMUM     1.888   5.119
#              GLP               28.026  79.192
#              GNV                0.996   3.399
#              ÓLEO DIESEL        1.356   3.994
#              ÓLEO DIESEL S10    2.180   4.080
# SUL          ETANOL HIDRATADO   0.922   4.287
#              GASOLINA COMUM     1.961   4.953
#              GLP               29.440  72.088
#              GNV                1.168   3.476
#              ÓLEO DIESEL        1.374   3.800
#              ÓLEO DIESEL S10    2.151   3.815

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas = notas.sort_values(by='nota_final', ascending=False)
notas = notas.reset_index(drop=True)
notas
# Out:
#     nome  idade  nota_final
# 0  Maria     21        10.0
# 1  Alice     20        10.0
# 2   José     19         6.0
# 3   João     20         5.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %%
notas = notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True])
notas
# Out:
#     nome  idade  nota_final
# 1  Alice     20        10.0
# 0  Maria     21        10.0
# 2   José     19         6.0
# 3   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
data_sep = data_final.query('ANO != 2019')
data_sep
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                    1.288                  0.016                 1.190  ...
# 1                    1.162                  0.114                 0.890  ...
# 2                    1.389                  0.097                 1.180  ...
# 3                    1.262                  0.070                 1.090  ...
# 4                    1.181                  0.078                 1.050  ...
# ...                    ...                    ...                   ...  ...
# 99734                3.080                  0.262                 2.798  ...
# 99735                3.465                  0.060                 3.370  ...
# 99736                3.402                  0.103                 3.199  ...
# 99737                2.944                  0.124                 2.790  ...
# 99738                2.353                  0.451                 1.999  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  COLUNA NOVA  \
# 0                              0.133    5  2004      Default
# 1                              0.115    5  2004      Default
# 2                              0.098    5  2004      Default
# 3                              0.143    5  2004      Default
# 4                              0.082    5  2004      Default
# ...                              ...  ...   ...          ...
# 99734                          0.068   12  2018      Default
# 99735                          0.000   12  2018      Default
# 99736                          0.118   12  2018      Default
# 99737                          0.124   12  2018      Default
# 99738                          0.133   12  2018      Default
#
#        coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                            0                       6.9552
# 1                            1                       6.2748
# 2                            2                       7.5006
# 3                            3                       6.8148
# 4                            4                       6.3774
# ...                        ...                          ...
# 99734                   103063                      16.6320
# 99735                   103064                      18.7110
# 99736                   103065                      18.3708
# 99737                   103066                      15.8976
# 99738                   103067                      12.7062
#
# [99739 rows x 23 columns]

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %%
data_sep.reset_index()
# Out:
#        index DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0          0   2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1          1   2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2          2   2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3          3   2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4          4   2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...      ...          ...         ...           ...                  ...
# 99734  99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735  99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736  99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737  99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738  99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                    1.288                  0.016  ...
# 1                    1.162                  0.114  ...
# 2                    1.389                  0.097  ...
# 3                    1.262                  0.070  ...
# 4                    1.181                  0.078  ...
# ...                    ...                    ...  ...
# 99734                3.080                  0.262  ...
# 99735                3.465                  0.060  ...
# 99736                3.402                  0.103  ...
# 99737                2.944                  0.124  ...
# 99738                2.353                  0.451  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  COLUNA NOVA  \
# 0                              0.133    5  2004      Default
# 1                              0.115    5  2004      Default
# 2                              0.098    5  2004      Default
# 3                              0.143    5  2004      Default
# 4                              0.082    5  2004      Default
# ...                              ...  ...   ...          ...
# 99734                          0.068   12  2018      Default
# 99735                          0.000   12  2018      Default
# 99736                          0.118   12  2018      Default
# 99737                          0.124   12  2018      Default
# 99738                          0.133   12  2018      Default
#
#        coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                            0                       6.9552
# 1                            1                       6.2748
# 2                            2                       7.5006
# 3                            3                       6.8148
# 4                            4                       6.3774
# ...                        ...                          ...
# 99734                   103063                      16.6320
# 99735                   103064                      18.7110
# 99736                   103065                      18.3708
# 99737                   103066                      15.8976
# 99738                   103067                      12.7062
#
# [99739 rows x 24 columns]

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em _uma nova coluna_ chamada 'index'. <br/>
# Para removê-la durante o _reset_, basta passarmos o argumento `drop=True`.

# %%
data_sep.reset_index(drop=True)
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                    1.288                  0.016                 1.190  ...
# 1                    1.162                  0.114                 0.890  ...
# 2                    1.389                  0.097                 1.180  ...
# 3                    1.262                  0.070                 1.090  ...
# 4                    1.181                  0.078                 1.050  ...
# ...                    ...                    ...                   ...  ...
# 99734                3.080                  0.262                 2.798  ...
# 99735                3.465                  0.060                 3.370  ...
# 99736                3.402                  0.103                 3.199  ...
# 99737                2.944                  0.124                 2.790  ...
# 99738                2.353                  0.451                 1.999  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  COLUNA NOVA  \
# 0                              0.133    5  2004      Default
# 1                              0.115    5  2004      Default
# 2                              0.098    5  2004      Default
# 3                              0.143    5  2004      Default
# 4                              0.082    5  2004      Default
# ...                              ...  ...   ...          ...
# 99734                          0.068   12  2018      Default
# 99735                          0.000   12  2018      Default
# 99736                          0.118   12  2018      Default
# 99737                          0.124   12  2018      Default
# 99738                          0.133   12  2018      Default
#
#        coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 0                            0                       6.9552
# 1                            1                       6.2748
# 2                            2                       7.5006
# 3                            3                       6.8148
# 4                            4                       6.3774
# ...                        ...                          ...
# 99734                   103063                      16.6320
# 99735                   103064                      18.7110
# 99736                   103065                      18.3708
# 99737                   103066                      15.8976
# 99738                   103067                      12.7062
#
# [99739 rows x 23 columns]

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %%
zap = data_final.groupby('REGIÃO')
zap['NÚMERO DE POSTOS PESQUISADOS'].sum()
# Out:
# REGIÃO
# CENTRO OESTE     2107548
# NORDESTE         4463545
# NORTE            1628063
# SUDESTE         12157283
# SUL              4510571
# Name: NÚMERO DE POSTOS PESQUISADOS, dtype: int64

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 103387               GNV                             7             R$/m3
# 103388               GNV                            23             R$/m3
# 103389               GNV                            24             R$/m3
# 103390               GNV                            52             R$/m3
# 103391               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 103387                3.574                  0.065                 3.499  ...
# 103388                3.401                  0.129                 3.230  ...
# 103389                2.912                  0.190                 2.699  ...
# 103390                3.020                  0.229                 2.699  ...
# 103391                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
#
SUDESTE  SAO PAULO  GASOLINA COMUM
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92319                          1641              R$/l                3.988
# 92465                          1648              R$/l                4.002
# 92610                          1648              R$/l                4.006
# 92755                          1644              R$/l                4.019
# 92901                          1646              R$/l                4.004
# 93048                          1640              R$/l                4.014
# 93192                          1637              R$/l                4.008
# 93339                          1638              R$/l                3.992
# 93487                          1637              R$/l                3.970
# 93634                          1644              R$/l                4.003
# 93778                          1644              R$/l                3.988
# 93924                          1643              R$/l                3.992
# 94070                          1646              R$/l                4.007
# 94215                          1646              R$/l                4.008
# 94361                          1645              R$/l                4.006
# 94508                          1643              R$/l                4.035
# 94656                          1644              R$/l                4.005
# 94804                          1644              R$/l                4.032
# 94951                          1643              R$/l                4.056
# 95098                          1619              R$/l                4.196
# 95211                           102              R$/l                4.502
# 95342                          1560              R$/l                4.416
# 95486                          1616              R$/l                4.349
# 95633                          1646              R$/l                4.326
# 95779                          1643              R$/l                4.274
# 95922                          1637              R$/l                4.272
# 96069                          1640              R$/l                4.259
# 96217                          1641              R$/l                4.268
# 96362                          1644              R$/l                4.241
# 96507                          1639              R$/l                4.235
# 96651                          1640              R$/l                4.221
# 96799                          1646              R$/l                4.208
# 96943                          1643              R$/l                4.189
# 97086                          1638              R$/l                4.224
# 97230                          1640              R$/l                4.296
# 97378                          1641              R$/l                4.409
# 97527                          1639              R$/l                4.414
# 97675                          1639              R$/l                4.476
# 97820                          1639              R$/l                4.469
# 97965                          1643              R$/l                4.499
# 98112                          1645              R$/l                4.512
# 98259                          1641              R$/l                4.506
# 98401                          1641              R$/l                4.490
# 98545                          1645              R$/l                4.452
# 98689                          1643              R$/l                4.377
# 98831                          1641              R$/l                4.332
# 98977                          1641              R$/l                4.291
# 99122                          1648              R$/l                4.187
# 99266                          1649              R$/l                4.148
# 99410                          1637              R$/l                4.129
# 99553                          1641              R$/l                4.129
# 99698                          1643              R$/l                4.113
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 92319                  0.156                 3.499  ...
# 92465                  0.155                 3.549  ...
# 92610                  0.160                 3.499  ...
# 92755                  0.156                 3.579  ...
# 92901                  0.157                 3.579  ...
# 93048                  0.153                 3.499  ...
# 93192                  0.161                 3.559  ...
# 93339                  0.164                 3.479  ...
# 93487                  0.161                 3.479  ...
# 93634                  0.155                 3.499  ...
# 93778                  0.154                 3.499  ...
# 93924                  0.159                 3.499  ...
# 94070                  0.171                 3.495  ...
# 94215                  0.161                 3.499  ...
# 94361                  0.159                 3.499  ...
# 94508                  0.168                 3.499  ...
# 94656                  0.158                 3.488  ...
# 94804                  0.171                 3.369  ...
# 94951                  0.160                 3.499  ...
# 95098                  0.187                 3.499  ...
# 95211                  0.199                 3.898  ...
# 95342                  0.155                 3.599  ...
# 95486                  0.150                 3.899  ...
# 95633                  0.157                 3.799  ...
# 95779                  0.167                 3.699  ...
# 95922                  0.178                 3.699  ...
# 96069                  0.168                 3.779  ...
# 96217                  0.171                 3.699  ...
# 96362                  0.175                 3.649  ...
# 96507                  0.182                 3.679  ...
# 96651                  0.192                 3.679  ...
# 96799                  0.189                 3.679  ...
# 96943                  0.189                 3.649  ...
# 97086                  0.185                 3.679  ...
luna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 92319                    95351                      21.5352
# 92465                    95502                      21.6108
# 92610                    95654                      21.6324
# 92755                    95806                      21.7026
# 92901                    95958                      21.6216
# 93048                    96109                      21.6756
# 93192                    96259                      21.6432
# 93339                    96411                      21.5568
# 93487                    96563                      21.4380
# 93634                    96715                      21.6162
# 93778                    96866                      21.5352
# 93924                    97017                      21.5568
# 94070                    97168                      21.6378
# 94215                    97319                      21.6432
# 94361                    97471                      21.6324
# 94508                    97622                      21.7890
# 94656                    97773                      21.6270
# 94804                    97924                      21.7728
# 94951                    98074                      21.9024
# 95098                    98225                      22.6584
# 95211                    98371                      24.3108
# 95342                    98517                      23.8464
# 95486                    98670                      23.4846
# 95633                    98821                      23.3604
# 95779                    98972                      23.0796
# 95922                    99122                      23.0688
# 96069                    99271                      22.9986
# 96217                    99422                      23.0472
# 96362                    99573                      22.9014
# 96507                    99725                      22.8690
# 96651                    99876                      22.7934
# 96799                   100027                      22.7232
# 96943                   100177                      22.6206
# 97086                   100326                      22.8096
# 97230                   100477                      23.1984
# 97378                   100628                      23.8086
# 97527                   100780                      23.8356
# 97675                   100930                      24.1704
# 97820                   101079                      24.1326
# 97965                   101228                      24.2946
# 98112                   101378                      24.3648
# 98259                   101529                      24.3324
# 98401                   101679                      24.2460
# 98545                   101828                      24.0408
# 98689                   101977                      23.6358
# 98831                   102127                      23.3928
# 98977                   102276                      23.1714
# 99122                   102426                      22.6098
# 99266                   102575                      22.3992
# 99410                   102724                      22.2966
# 99553                   102874                      22.2966
# 99698                   103025                      22.2102
#
# [52 rows x 23 columns]

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
data_sep.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                     52.000000            52.000000
# mean                    1610.211538             4.202769
# std                      213.627432             0.180672
# min                      102.000000             3.970000
# 25%                     1639.000000             4.008000
# 50%                     1642.000000             4.202000
# 75%                     1644.000000             4.336250
# max                     1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# min                 0.150000              3.369000              4.499000
# 25%                 0.159750              3.499000              4.899000
# 50%                 0.173000              3.679000              4.999000
# 75%                 0.189000              3.784000              5.099000
# max                 0.216000              3.969000              5.299000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count             52.000000                 52.000000
# mean               0.442481                  0.041750
# std                0.063271                  0.003965
# min                0.366000                  0.034000
# 25%                0.404500                  0.039000
# 50%                0.421500                  0.040000
# 75%                0.470250                  0.044000
# max                0.640000                  0.051000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count                 52.000000                   52.000000
# mean                   3.760288                    0.109654
# std                    0.163664                    0.010712
# min                    3.563000                    0.087000
# 25%                    3.620250                    0.102000
# 50%                    3.756500                    0.108000
# 75%                    3.862250                    0.116250
# max                    4.085000                    0.144000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count                   52.00000                  52.000000
# mean                     3.31295                   4.139454
# std                      0.26684                   0.195897
# min                      2.92400                   3.887500
# 25%                      2.99000                   3.965775
# 50%                      3.35000                   4.095500
# 75%                      3.53250                   4.259000
# max                      3.76000                   4.551000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO        MÊS     ANO  \
# count                      52.000000  52.000000    52.0
# mean                        0.029096   6.615385  2018.0
# std                         0.002460   3.470627     0.0
# min                         0.023000   1.000000  2018.0
# 25%                         0.028000   4.000000  2018.0
# 50%                         0.029000   7.000000  2018.0
# 75%                         0.030000   9.250000  2018.0
# max                         0.037000  12.000000  2018.0
#
#        coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# count                52.000000                    52.000000
# mean              99196.096154                    22.694954
# std                2279.595314                     0.975629
# min               95351.000000                    21.438000
# 25%               97281.250000                    21.643200
# 50%               99196.500000                    22.690800
# 75%              101116.250000                    23.415750
# max              103025.000000                    24.364800

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
data_sep = data_final.query("PRODUTO == 'GASOLINA COMUM' | PRODUTO == 'ETANOL HIDRATADO'")
data_sep = data_sep.query("ESTADO == 'SAO PAULO' & ANO == 2018")
data_sep
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...            ...         ...      ...        ...               ...
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92238                          1664              R$/l                2.833
# 92319                          1641              R$/l                3.988
# 92384                          1661              R$/l                2.868
# 92465                          1648              R$/l                4.002
# 92529                          1662              R$/l                2.874
# ...                             ...               ...                  ...
# 99410                          1637              R$/l                4.129
# 99472                          1662              R$/l                2.644
# 99553                          1641              R$/l                4.129
# 99617                          1661              R$/l                2.643
# 99698                          1643              R$/l                4.113
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 92238                  0.139                 2.449  ...
# 92319                  0.156                 3.499  ...
# 92384                  0.134                 2.399  ...
# 92465                  0.155                 3.549  ...
# 92529                  0.135                 2.399  ...
# ...                      ...                   ...  ...
# 99410                  0.201                 3.699  ...
# 99472                  0.163                 2.149  ...
# 99553                  0.201                 3.699  ...
# 99617                  0.161                 2.259  ...
# 99698                  0.201                 3.599  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 92238                     2.495                       0.092
# 92319                     3.577                       0.104
# 92384                     2.537                       0.087
# 92465                     3.590                       0.102
# 92529                     2.550                       0.095
# ...                         ...                         ...
# 99410                     3.639                       0.110
# 99472                     2.339                       0.094
# 99553                     3.645                       0.107
# 99617                     2.340                       0.097
# 99698                     3.610                       0.100
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 92238                     2.1842                     2.8833
# 92319                     2.9900                     3.9510
# 92384                     2.2600                     2.8471
# 92465                     2.9900                     3.9014
# 92529                     1.6900                     2.9722
# ...                          ...                        ...
# 99410                     3.3500                     3.9892
# 99472                     2.0067                     2.7443
# 99553                     3.3500                     3.9892
# 99617                     1.9072                     2.7957
# 99698                     3.3500                     3.9585
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  COLUNA NOVA  \
# 92238                          0.037    1  2018      Default
# 92319                          0.029    1  2018      Default
# 92384                          0.034    1  2018      Default
# 92465                          0.028    1  2018      Default
# 92529                          0.037    1  2018      Default
# ...                              ...  ...   ...          ...
# 99410                          0.030   12  2018      Default
# 99472                          0.040   12  2018      Default
# 99553                          0.029   12  2018      Default
# 99617                          0.041   12  2018      Default
# 99698                          0.028   12  2018      Default
#
#        coluna criada com lista  PRECO MEDIO REVENDA (Dólar)
# 92238                    95270                      15.2982
# 92319                    95351                      21.5352
# 92384                    95421                      15.4872
# 92465                    95502                      21.6108
# 92529                    95573                      15.5196
# ...                        ...                          ...
# 99410                   102724                      22.2966
# 99472                   102793                      14.2776
# 99553                   102874                      22.2966
# 99617                   102944                      14.2722
# 99698                   103025                      22.2102
#
# [104 rows x 23 columns]

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
